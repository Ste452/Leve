# %%
pip install python-docx
# Out:
# Requirement already satisfied: python-docx in c:\users\micro\alunopython\myanaconda\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\micro\alunopython\myanaconda\anaconda3\lib\site-packages (from python-docx) (4.9.3)
# Requirement already satisfied: typing-extensions in c:\users\micro\alunopython\myanaconda\anaconda3\lib\site-packages (from python-docx) (4.7.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from docx import Document
from docx.shared import Pt

#Abrindo o arquivo do Word
arquivoWord = Document("Certificado1.docx")

#Configurando os estilos
estilo = arquivoWord.styles["Normal"]

#for = para
for paragrafo in arquivoWord.paragraphs:
    #if = se
    if "@nome" in paragrafo.text:
        paragrafo.text = "Amanda Batista Alves"
        fonte = estilo.font
        fonte.name = "Calibri (Corpo)"
        fonte.size = Pt(24)
        

#Salva o certificado com o nome do aluno
arquivoWord.save("Amanda Batista Alves.docx")

print("Certificado gerado com sucesso!")
# Out:
# ---------------------------------------------------------------------------
# PackageNotFoundError                      Traceback (most recent call last)
# Cell In[7], line 5
#       2 from docx.shared import Pt
#       4 #Abrindo o arquivo do Word
# ----> 5 arquivoWord = Document("Certificado1.docx")
#       7 #Configurando os estilos
#       8 estilo = arquivoWord.styles["Normal"]
#
# File ~\AlunoPython\MyAnaconda\anaconda3\Lib\site-packages\docx\api.py:23, in Document(docx)
#      16 """Return a |Document| object loaded from `docx`, where `docx` can be either a path
#      17 to a ``.docx`` file (a string) or a file-like object.
#      18
#      19 If `docx` is missing or ``None``, the built-in default document "template" is
#      20 loaded.
#      21 """
#      22 docx = _default_docx_path() if docx is None else docx
# ---> 23 document_part = Package.open(docx).main_document_part
#      24 if document_part.content_type != CT.WML_DOCUMENT_MAIN:
#      25     tmpl = "file '%s' is not a Word file, content type is '%s'"
#
# File ~\AlunoPython\MyAnaconda\anaconda3\Lib\site-packages\docx\opc\package.py:116, in OpcPackage.open(cls, pkg_file)
#     113 @classmethod
#     114 def open(cls, pkg_file):
#     115     """Return an |OpcPackage| instance loaded with the contents of `pkg_file`."""
# --> 116     pkg_reader = PackageReader.from_file(pkg_file)
#     117     package = cls()
#     118     Unmarshaller.unmarshal(pkg_reader, package, PartFactory)
#
# File ~\AlunoPython\MyAnaconda\anaconda3\Lib\site-packages\docx\opc\pkgreader.py:22, in PackageReader.from_file(pkg_file)
#      19 @staticmethod
#      20 def from_file(pkg_file):
#      21     """Return a |PackageReader| instance loaded with contents of `pkg_file`."""
# ---> 22     phys_reader = PhysPkgReader(pkg_file)
#      23     content_types = _ContentTypeMap.from_xml(phys_reader.content_types_xml)
#      24     pkg_srels = PackageReader._srels_for(phys_reader, PACKAGE_URI)
#
# File ~\AlunoPython\MyAnaconda\anaconda3\Lib\site-packages\docx\opc\phys_pkg.py:21, in PhysPkgReader.__new__(cls, pkg_file)
#      19         reader_cls = _ZipPkgReader
#      20     else:
# ---> 21         raise PackageNotFoundError("Package not found at '%s'" % pkg_file)
#      22 else:  # assume it's a stream and pass it to Zip reader to sort out
#      23     reader_cls = _ZipPkgReader
#
# PackageNotFoundError: Package not found at 'Certificado1.docx'

# %%
from docx import Document
from docx.shared import Pt

from openpyxl import load_workbook
import os

#Configurando o caminho
nome_arquivo_alunos = "C:\\Users\\Desktop\\Leveling_python\\13_section_Python_and_Word_generating_Certificates\\excel\\Students.xlsx"

#Abrindo o arquivo
planilhaDadosAlunos = load_workbook(nome_arquivo_alunos)

#Selecionando a aba sheet/planilha
sheet_selecionada = planilhaDadosAlunos["Nomes"]

#for = para
for linha in range(2, len(sheet_selecionada["A"]) + 1):

    #Abrindo o arquivo do Word
    arquivoWord = Document("Certificado1.docx")

    #Configurando os estilos
    estilo = arquivoWord.styles["Normal"]
    
    #Pegamos o nome do aluno que está na linha corrente
    nomeAluno = sheet_selecionada['A%s' % linha].value

    #for = para
    for paragrafo in arquivoWord.paragraphs:
        #if = se
        if "@nome" in paragrafo.text:
            paragrafo.text = nomeAluno
            fonte = estilo.font
            fonte.name = "Calibri (Corpo)"
            fonte.size = Pt(24)

    caminhoCertificado = "C:\\Users\\Desktop\\Leveling_python\\Doc_document\\" + nomeAluno + ".docx"

    #Salva o certificado com o nome do aluno
    arquivoWord.save(caminhoCertificado)

print("Certificados gerados com sucesso!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from docx import Document
#       2 from docx.shared import Pt
#       4 from openpyxl import load_workbook
#
# ModuleNotFoundError: No module named 'docx'

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\55119\anaconda3\lib\site-packages (3.0.7)
# Requirement already satisfied: et-xmlfile in c:\users\55119\anaconda3\lib\site-packages (from openpyxl) (1.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from docx import Document
from docx.shared import Pt

from openpyxl import load_workbook
import os

#Configurando o caminho
nome_arquivo_alunos = "C:\\Users\\55119\\Desktop\\Curso RPA\\Word\\DadosAlunos.xlsx"

#Abrindo o arquivo
planilhaDadosAlunos = load_workbook(nome_arquivo_alunos)

#Selecionando a aba sheet/planilha
sheet_selecionada = planilhaDadosAlunos["Nomes"]

#for = para
for linha in range(2, len(sheet_selecionada["A"]) + 1):

    #Abrindo o arquivo do Word
    arquivoWord = Document("Certificado2.docx")

    #Configurando os estilos
    estilo = arquivoWord.styles["Normal"]
    
    #Pegamos o nome do aluno que está na linha corrente
    nomeAluno = sheet_selecionada['A%s' % linha].value
    dia = sheet_selecionada['B%s' % linha].value
    mes = sheet_selecionada['C%s' % linha].value
    ano = sheet_selecionada['D%s' % linha].value
    nomeCurso = sheet_selecionada['E%s' % linha].value
    nomeInstrutor = sheet_selecionada['F%s' % linha].value
    
    frase_parte1 = "Concluiu com sucesso o curso de "
    frase_parte2 = ", com a carga horária de 20 horas, promovido pela escola de Cursos Online em "
    frase_montada = f"{frase_parte1} {nomeCurso}{frase_parte2} {dia} de {mes} de {ano}"

    #for = para
    for paragrafo in arquivoWord.paragraphs:
        #if = se
        if "@nome" in paragrafo.text:
            paragrafo.text = nomeAluno
            fonte = estilo.font
            fonte.name = "Calibri (Corpo)"
            fonte.size = Pt(24)
            
        if "Dezembro" in paragrafo.text:
            paragrafo.text = frase_montada
            fonte = estilo.font
            fonte.name = "Calibri (Corpo)"
            fonte.size = Pt(24)
            
        if "Instrutor" in paragrafo.text:
            paragrafo.text = nomeInstrutor + " - Instrutor"
            fonte = estilo.font
            fonte.name = "Calibri (Corpo)"
            fonte.size = Pt(24)

    caminhoCertificado = "C:\\Users\\55119\\Desktop\\Curso RPA\\Word\\Certificados\\" + nomeAluno + ".docx"

    #Salva o certificado com o nome do aluno
    arquivoWord.save(caminhoCertificado)

print("Certificados gerados com sucesso!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from docx import Document
#       2 from docx.shared import Pt
#       4 from openpyxl import load_workbook
#
# ModuleNotFoundError: No module named 'docx'

# %%
from docx import Document

#Aumenta o tamanho da fonte
from docx.shared import Pt

#Mudar a cor da fonte
from docx.shared import RGBColor

#Abre o arquivo de excel
from openpyxl import load_workbook


#Configurando o caminho
nome_arquivo_alunos = "C:\\Users\\55119\\Desktop\\Curso RPA\\Word\\DadosAlunos.xlsx"

#Abrindo o arquivo
planilhaDadosAlunos = load_workbook(nome_arquivo_alunos)

#Selecionando a aba sheet/planilha
sheet_selecionada = planilhaDadosAlunos["Nomes"]

#for = para
for linha in range(2, len(sheet_selecionada["A"]) + 1):

    #Abrindo o arquivo do Word
    arquivoWord = Document("Certificado2.docx")

    #Configurando os estilos
    estilo = arquivoWord.styles["Normal"]
    
    #Pegamos o nome do aluno que está na linha corrente
    nomeAluno = sheet_selecionada['A%s' % linha].value
    dia = sheet_selecionada['B%s' % linha].value
    mes = sheet_selecionada['C%s' % linha].value
    ano = sheet_selecionada['D%s' % linha].value
    nomeCurso = sheet_selecionada['E%s' % linha].value
    nomeInstrutor = sheet_selecionada['F%s' % linha].value
    
    frase_parte1 = "Concluiu com sucesso o curso de "
    frase_parte2 = ", com a carga horária de 20 horas, promovido pela escola de Cursos Online em "
    frase_montada = f"{frase_parte2} {dia} de {mes} de {ano}"

    #for = para
    for paragrafo in arquivoWord.paragraphs:
        #if = se
        if "@nome" in paragrafo.text:
            paragrafo.text = nomeAluno
            fonte = estilo.font
            fonte.name = "Calibri (Corpo)"
            fonte.size = Pt(24)
            
        if "Dezembro" in paragrafo.text:
            paragrafo.text = frase_parte1
            fonte = estilo.font
            fonte.name = "Calibri (Corpo)"
            fonte.size = Pt(24)
            adicionaNovaPalavra = paragrafo.add_run(nomeCurso) #Adiciona o nome do curso no final do paragrafo
            adicionaNovaPalavra.font.color.rgb = RGBColor(255, 0, 0) #Muda a cor para vermelho
            adicionaNovaPalavra.underline = True #Subrinha a palavra
            adicionaNovaPalavra.bold = True #Deixa a palavra como negrito
            adicionaNovaPalavra = paragrafo.add_run(frase_montada) #Adiciona o texto final do paragrafo
            adicionaNovaPalavra.font.color.rgb = RGBColor(0, 0, 0) #Muda a cor para preto
            
        if "Instrutor" in paragrafo.text:
            paragrafo.text = nomeInstrutor + " - Instrutor"
            fonte = estilo.font
            fonte.name = "Calibri (Corpo)"
            fonte.size = Pt(24)

    caminhoCertificado = "C:\\Users\\55119\\Desktop\\Curso RPA\\Word\\Certificados\\" + nomeAluno + ".docx"

    #Salva o certificado com o nome do aluno
    arquivoWord.save(caminhoCertificado)

print("Certificados gerados com sucesso!")
# Out:
# Certificados gerados com sucesso!

# %%
pip install pywin32
# Out:
# Requirement already satisfied: pywin32 in c:\users\55119\anaconda3\lib\site-packages (227)
# Note: you may need to restart the kernel to use updated packages.

# %%
from docx import Document

#Aumenta o tamanho da fonte
from docx.shared import Pt

#Mudar a cor da fonte
from docx.shared import RGBColor

#Abre o arquivo de excel
from openpyxl import load_workbook

import win32com.client as win32
outlook = win32.Dispatch("outlook.application")


#Configurando o caminho
nome_arquivo_alunos = "C:\\Users\\55119\\Desktop\\Curso RPA\\Word\\DadosAlunosEmail.xlsx"

#Abrindo o arquivo
planilhaDadosAlunos = load_workbook(nome_arquivo_alunos)

#Selecionando a aba sheet/planilha
sheet_selecionada = planilhaDadosAlunos["Nomes"]

#for = para
for linha in range(2, len(sheet_selecionada["A"]) + 1):

    #Abrindo o arquivo do Word
    arquivoWord = Document("Certificado2.docx")

    #Configurando os estilos
    estilo = arquivoWord.styles["Normal"]
    
    #Pegamos o nome do aluno que está na linha corrente
    nomeAluno = sheet_selecionada['A%s' % linha].value
    dia = sheet_selecionada['B%s' % linha].value
    mes = sheet_selecionada['C%s' % linha].value
    ano = sheet_selecionada['D%s' % linha].value
    nomeCurso = sheet_selecionada['E%s' % linha].value
    nomeInstrutor = sheet_selecionada['F%s' % linha].value
    emailAluno = sheet_selecionada['G%s' % linha].value
    
    frase_parte1 = "Concluiu com sucesso o curso de "
    frase_parte2 = ", com a carga horária de 20 horas, promovido pela escola de Cursos Online em "
    frase_montada = f"{frase_parte2} {dia} de {mes} de {ano}."

    #for = para
    for paragrafo in arquivoWord.paragraphs:
        #if = se
        if "@nome" in paragrafo.text:
            paragrafo.text = nomeAluno
            fonte = estilo.font
            fonte.name = "Calibri (Corpo)"
            fonte.size = Pt(24)
            
        if "Dezembro" in paragrafo.text:
            paragrafo.text = frase_parte1
            fonte = estilo.font
            fonte.name = "Calibri (Corpo)"
            fonte.size = Pt(24)
            adicionaNovaPalavra = paragrafo.add_run(nomeCurso) #Adiciona o nome do curso no final do paragrafo
            adicionaNovaPalavra.font.color.rgb = RGBColor(255, 0, 0) #Muda a cor para vermelho
            adicionaNovaPalavra.underline = True #Subrinha a palavra
            adicionaNovaPalavra.bold = True #Deixa a palavra como negrito
            adicionaNovaPalavra = paragrafo.add_run(frase_montada) #Adiciona o texto final do paragrafo
            adicionaNovaPalavra.font.color.rgb = RGBColor(0, 0, 0) #Muda a cor para preto
            
        if "Instrutor" in paragrafo.text:
            paragrafo.text = nomeInstrutor + " - Instrutor"
            fonte = estilo.font
            fonte.name = "Calibri (Corpo)"
            fonte.size = Pt(24)

    caminhoCertificado = "C:\\Users\\55119\\Desktop\\Curso RPA\\Word\\Certificados\\" + nomeAluno + ".docx"

    #Salva o certificado com o nome do aluno
    arquivoWord.save(caminhoCertificado)
    
    emailOutlook = outlook.CreateItem(0)
    
    #Pegando o primeiro nome
    primeiroNome = nomeAluno.split(None, 1)[0]
    
    emailOutlook.To = emailAluno
    emailOutlook.Subject = "Certificado " + nomeAluno
    emailOutlook.HTMLBody = f"""
        <p>Boa noite {primeiroNome}.</p>
        <p>Segue seu <b>certificado</b>.</p>
        <p>Atenciosamente. </p>
        <p><img src="C:\\Users\\55119\\Desktop\\Curso RPA\\Word\\Assinatura.jpg"></p>
    """
    #Adicionando o certificado em anexo
    emailOutlook.Attachments.Add(caminhoCertificado)
    emailOutlook.save() #save = cria e salva como draft - send - envia o email direto

print("Certificados gerados com sucesso!")
# Out:
# Certificados gerados com sucesso!
